# %% [markdown]
# <a href="https://colab.research.google.com/github/pi-recious/DataProcessing/blob/master/Dataset2hackathon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Link collab to drive
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/My\ Drive
# Out:
# /content/drive/My Drive

# %%
import io
import pandas as pd

# %%
df=pd.read_csv("Ethnicitybygender.csv")
df #print data frame
# Out:
#                             Ethnic Group  ...  Females death rate ages:65+
# 0                                  White  ...                        0.366
# 1                                  Mixed  ...                        0.266
# 2                                 Indian  ...                        0.329
# 3              Pakistani and Bangladeshi  ...                        0.244
# 4                                Chinese  ...                        0.254
# 5  Black/African/Caribbean/Black British  ...                        0.304
# 6                     Other ethnic group  ...                        0.268
#
# [7 rows x 6 columns]

# %% [markdown]
# Exploratory Data Analysis and Findings

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 6 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Ethnic Group                            7 non-null      object
#  1   Weighted Population by Covid DeathRate  7 non-null      float64
#  2   Males death rate ages:0-64              7 non-null      float64
#  3   Female Death rate 0-65                  7 non-null      float64
#  4   Males death rate ages:65+               7 non-null      float64
#  5   Females death rate ages:65+             7 non-null      float64
# dtypes: float64(5), object(1)
# memory usage: 464.0+ bytes
#        Weighted Population by Covid DeathRate  ...  Females death rate ages:65+
# count                                7.000000  ...                     7.000000
# mean                                 1.067571  ...                     0.290143
# ...

# %%
df_floats =df.iloc[0:22].drop(['Ethnic Group'], axis=1) #new dataframe created.head()
df_floats.columns
# Out:
# Index(['Weighted Population by Covid DeathRate', 'Males death rate ages:0-64',
#        'Female Death rate 0-65', 'Males death rate ages:65+',
#        'Females death rate ages:65+'],
#       dtype='object')

# %%
#Importing libraries for data visualization

import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df_floats.plot.barh(figsize=(28,10))
plt.rcParams["font.size"] =15

plt.title('COVID-19 Death Rate by Gender, age and Ethnicty by Population', fontdict={"fontname": "Arial", 'fontsize': 35})
plt.yticks(range(len(df)), df["Ethnic Group"])
plt.ylabel("Ethnic Group")
plt.xlabel("Proportion")
# Out:
# Text(0.5, 0, 'Proportion')

# %%
df_float.plot.line()

# %%
df_floats[['Males death rate ages:0-64',
       'Female Death rate 0-65', 'Males death rate ages:65+',
       'Females death rate ages:65+']].plot.barh(figsize=(25,10))
plt.rcParams["font.size"] = 20
plt.title('COVID-19 Death Rate by Gender, age and Ethnicty', fontdict={"fontname": "Arial", 'fontsize': 35})
plt.yticks(range(len(df)), df["Ethnic Group"])
plt.ylabel("Ethnic Group")
plt.xlabel("Proportion")
# Out:
# Text(0.5, 0, 'Proportion')
